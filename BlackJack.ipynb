# %%
import random

class Card():   
    def __init__(self, category, name, value):
        # private attributes, Python uses the __ as convention
        self.__category = category 
        self.__name = name
        self.__value = value
        
    def __str__(self):
        return f"{self.__name} of {self.__category} ({self.__value})"
    
    def set_value(self, value):
        self.__value = value


class Deck():
    CARD_CATEGORIES = ["Spades", "Hearts", "Diamonds", "Clubs"]
    CARD_VALUES = {"Ace":-1, "Two":2, "Three":3, "Four":4, "Five":5, "Six":6, "Seven":7, "Eight":8, "Nine":9, "Ten":10, "Jack":10, "Queen":10, "King":10}
    
    def __init__(self):
        self.__total_cards = 52
        self.cards = []
        
        # Create our deck for blackjack and shuffle it
        for card in self.CARD_VALUES:
            for category in self.CARD_CATEGORIES:
                self.cards.append(Card(category, card, self.CARD_VALUES[card]))
        
        # Shuffle our deck
        self.shuffle()
        
    def shuffle(self):
        random.shuffle(self.cards)
    
    def top_card(self):
        # Takes the first card of the deck and returns it
        # No need to control the case of the deck being empty, this will never happen in this game
        self.__total_cards-=1
        return self.cards.pop(0)
    
    def __str__(self):
        # Pretty sure this is not the way to do this LUL
        print(f"Total cards:{self.__total_cards}")
        for card in self.cards:
            print(card)
        return ""
    
class Hand():
    def __init__(self):
        self.__cards = [] # private attribute
    
    def draw(self, deck):
        self.__cards.append(deck.top_card())
    
    def value(self):
        return sum(card.value for card in self.__cards)
        
    def __str__(self):
        # Pretty sure this is not the way to do this LUL
        print(f"Total cards:{len(self.__cards)}")
        for card in self.__cards:
            print(card)
        return ""


# TODO: this should be an abstract class -> Continue from HERE.
class Player():
    def __init__(self, savings):
        self._savings = savings
        self._hand = Hand()
        pass
      
    def draw(self,deck):
        self._hand.draw(deck)
    
    def print_hand(self):
        print(self._hand)
    
    def hit():
        pass
    
    
    
class HumanPlayer(Player):
    def __init__(self,savings=100):
        Player.__init__(self,savings)
        pass
    
    def stand():
        pass
    
    def bet(amount):
        pass
    
class Dealer(Player):
    def __init__(self):
        pass
    
    
my_deck = Deck()
print(my_deck)

human_player = HumanPlayer()
human_player.draw(my_deck)

print(my_deck)
# Out:
# Total cards:52
# Jack of Clubs (10)
# Six of Diamonds (6)
# Seven of Diamonds (7)
# Ten of Diamonds (10)
# King of Diamonds (10)
# Eight of Clubs (8)
# Five of Spades (5)
# Seven of Clubs (7)
# Ten of Spades (10)
# Nine of Clubs (9)
